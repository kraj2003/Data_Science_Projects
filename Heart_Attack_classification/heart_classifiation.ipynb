# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("datasets/heart_2020_cleaned.csv")
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
col=['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke',
 'MentalHealth', 'DiffWalking', 'Sex', 'Diabetic', 'PhysicalActivity',
       'Asthma', 'KidneyDisease', 'SkinCancer']

# %%
df[col]=df[col].apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race  Diabetic  \
# 0            30            0    0        55-59  White         2
# 1             0            0    0  80 or older  White         0
# 2            30            0    1        65-69  White         2
# 3             0            0    0        75-79  White         0
# 4             0            1    0        40-44  White         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
df.dtypes
# Out:
# HeartDisease          int32
# BMI                 float64
# Smoking               int32
# AlcoholDrinking       int32
# Stroke                int32
# PhysicalHealth      float64
# MentalHealth          int64
# DiffWalking           int32
# Sex                   int32
# AgeCategory          object
# Race                 object
# Diabetic              int32
# PhysicalActivity      int32
# GenHealth            object
# SleepTime           float64
# Asthma                int32
# KidneyDisease         int32
# SkinCancer            int32
# dtype: object

# %%
fig,ax=plt.subplots(figsize=(18,12))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race  Diabetic  \
# 0            30            0    0        55-59  White         2
# 1             0            0    0  80 or older  White         0
# 2            30            0    1        65-69  White         2
# 3             0            0    0        75-79  White         0
# 4             0            1    0        40-44  White         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
df[['PhysicalHealth','SleepTime']]=df[['PhysicalHealth','SleepTime']].astype(int)
df.head(2)
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race  Diabetic  \
# 0            30            0    0        55-59  White         2
# 1             0            0    0  80 or older  White         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1  Very good          5       1              0           1
# 1                 1  Very good          7       0              0           0

# %%
df.shape
# Out:
# (319795, 18)

# %%
df['GenHealth'].value_counts().to_frame()
# Out:
#             count
# GenHealth
# Very good  113858
# Good        93129
# Excellent   66842
# Fair        34677
# Poor        11289

# %%
sns.countplot(x=df['GenHealth'],data=df)
# sns.boxplot(x=df['GenHealth'],y=df['HeartDisease'],data=df)
# Out:
# <Axes: xlabel='GenHealth', ylabel='count'>

# %%
# sns.countplot(x=df['HeartDisease'],data=df) 
values=df['HeartDisease'].value_counts().tolist()
names=list(dict(df['HeartDisease'].value_counts()).keys())
name=['Heart disease reported','not reported']
plt.pie(values,labels=name,autopct="%5.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x26f42356e10>,
# ...
#  [Text(-1.0604682899620466, 0.2922447706717311, 'Heart disease reported'),
#   Text(1.0604682626001118, -0.2922448699599368, 'not reported')],
#  [Text(-0.5784372490702072, 0.15940623854821695, ' 91.4%'),
#   Text(0.5784372341455155, -0.15940629270542006, '  8.6%')])

# %%
variables=df[["Smoking",'AlcoholDrinking', 'Stroke',
 'MentalHealth', 'DiffWalking', 'Diabetic', 'PhysicalActivity',
       'Asthma', 'KidneyDisease', 'SkinCancer']]

sns.regplot(y=df['HeartDisease'],x=df["Stroke"],data=df)
# Out:
# <Axes: xlabel='Stroke', ylabel='HeartDisease'>

# %%
x=df.drop('HeartDisease',axis=1)
# x
y=df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(variables,y,test_size=0.10,random_state=1)
print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 31980
# number of training samples: 287815

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
yhat=lr.predict(x_test)
yhat
# Out:
# array([0.01607799, 0.47583031, 0.06303765, ..., 0.24115389, 0.02146217,
#        0.20976135])

# %%
score=lr.score(x_test,y_test)
score*100
# Out:
# 10.404957279981364

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
yhat=lr.predict(x_test)
yhat

# %%
rfc.score(x_test,y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

# %%
knn.score(x_test,y_test)
