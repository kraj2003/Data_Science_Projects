# %%
# importing the libraries and reading house_prices.csv
import pandas as pd
import numpy as np
file=pd.read_csv("datasets/house_prices.csv")
file.head(3)
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1            13799.0    thane    473 sqft  Ready to Move   3 out of 22
# 2            17500.0    thane    779 sqft  Ready to Move  10 out of 29
#
#   Transaction  ... facing  overlooking                              Society  \
# ...

# %%
file.shape
# Out:
# (187531, 21)

# %%
file.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Description            3023
# Amount(in rupees)         0
# Price (in rupees)     17665
# location                  0
# Carpet Area           80673
# Status                  615
# Floor                  7077
# Transaction              83
# Furnishing             2897
# facing                70233
# overlooking           81436
# Society              109678
# Bathroom                828
# Balcony               48935
# Car Parking          103357
# Ownership             65517
# Super Area           107685
# Dimensions           187531
# Plot Area            187531
# dtype: int64

# %%
# droping columns that has many null values and the one which are not to be used
file.drop(columns=["Dimensions","Plot Area","Super Area","Society","Car Parking",'Price (in rupees)','Transaction','facing',"overlooking","Index"],inplace=True)
file.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#   location Carpet Area         Status         Floor      Furnishing Bathroom  \
# 0    thane    500 sqft  Ready to Move  10 out of 11     Unfurnished        1
# ...

# %%
file.duplicated().sum()
# Out:
# 119400

# %%
# droping the rows that has null values in it
file.dropna(inplace=True)
file.head()
file.isnull().sum()
# Out:
# Title                0
# Description          0
# Amount(in rupees)    0
# location             0
# Carpet Area          0
# Status               0
# Floor                0
# Furnishing           0
# Bathroom             0
# Balcony              0
# Ownership            0
# dtype: int64

# %%
file.shape
# Out:
# (81460, 11)

# %%
# sorting by house prices
house_prices=file.sort_values(by="Amount(in rupees)", ascending=True)
house_prices.head(5)
# Out:
#                                                     Title  \
# 143858  3 BHK Ready to Occupy Flat for sale in Gaur Ci...
# 17880   2 BHK Ready to Occupy Flat for sale Whitefield...
# 2942    3 BHK Ready to Occupy Flat for sale in Shaligr...
# 154654  3 BHK Ready to Occupy Flat for sale Sector 37,...
# 155479  3 BHK Ready to Occupy Flat for sale in BPTP Pa...
#
#                                               Description Amount(in rupees)  \
# 143858  3 BHK flat available for sale in Noida in the ...             1 Cr
# 17880   Up for immediate sale is a 2 BHK apartment in ...             1 Cr
# 2942    This lovely 3 BHK Flat in South Bopal, Ahmedab...             1 Cr
# 154654  This magnificent 3 BHK Flat is available for s...             1 Cr
# 155479  This lovely 3 BHK Flat in Sector 75, Faridabad...             1 Cr
#
#          location Carpet Area         Status         Floor      Furnishing  \
# 143858      noida    950 sqft  Ready to Move  15 out of 32     Unfurnished
# ...

# %%
# houses that are in goa 
goa=house_prices.loc[house_prices['location']=='goa']
goa.head(3)
# Out:
#                                                 Title  \
# 159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 159468     2 BHK Ready to Occupy Flat for sale Siolim
# 159948  2 BHK Ready to Occupy Flat for sale Calangute
#
#                                               Description Amount(in rupees)  \
# 159794  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159468  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159948  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
#
#        location Carpet Area         Status       Floor   Furnishing Bathroom  \
# 159794      goa     111 sqm  Ready to Move  1 out of 3    Furnished        2
# 159468      goa      79 sqm  Ready to Move  1 out of 3  Unfurnished        2
# 159948      goa      93 sqm  Ready to Move  2 out of 2    Furnished        2
#
#        Balcony Ownership
# 159794       4  Freehold
# 159468       4  Freehold
# 159948       1  Freehold

# %%
# filtering out the furnished houses
furnished=goa.loc[house_prices['Furnishing']=='Furnished']
furnished.head(3)
# Out:
#                                                 Title  \
# 159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 159948  2 BHK Ready to Occupy Flat for sale Calangute
# 159981    1 BHK Ready to Occupy Flat for sale Assagao
#
#                                               Description Amount(in rupees)  \
# 159794  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159948  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
# 159981  Assagao, Goa has an attractive 1 BHK Flat for ...             1 Cr
#
#        location Carpet Area         Status            Floor Furnishing  \
# 159794      goa     111 sqm  Ready to Move       1 out of 3  Furnished
# 159948      goa      93 sqm  Ready to Move       2 out of 2  Furnished
# 159981      goa      56 sqm  Ready to Move  Ground out of 3  Furnished
#
#        Bathroom Balcony Ownership
# 159794        2       4  Freehold
# 159948        2       1  Freehold
# 159981        1       2  Freehold

# %%
# filter on ownership
ownership=furnished.loc[furnished['Ownership'].isin(['Freehold','Co-operative Society'])]
ownership.head(3)
# furnished['Ownership'].unique()
# Out:
#                                                 Title  \
# 159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 159948  2 BHK Ready to Occupy Flat for sale Calangute
# 159981    1 BHK Ready to Occupy Flat for sale Assagao
#
#                                               Description Amount(in rupees)  \
# 159794  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159948  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
# 159981  Assagao, Goa has an attractive 1 BHK Flat for ...             1 Cr
#
#        location Carpet Area         Status            Floor Furnishing  \
# 159794      goa     111 sqm  Ready to Move       1 out of 3  Furnished
# 159948      goa      93 sqm  Ready to Move       2 out of 2  Furnished
# 159981      goa      56 sqm  Ready to Move  Ground out of 3  Furnished
#
#        Bathroom Balcony Ownership
# 159794        2       4  Freehold
# 159948        2       1  Freehold
# 159981        1       2  Freehold

# %%
# filter on status
status=ownership.loc[ownership['Status']=='Ready to Move']
status.head(3)
# Out:
#                                                 Title  \
# 159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 159948  2 BHK Ready to Occupy Flat for sale Calangute
# 159981    1 BHK Ready to Occupy Flat for sale Assagao
#
#                                               Description Amount(in rupees)  \
# 159794  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159948  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
# 159981  Assagao, Goa has an attractive 1 BHK Flat for ...             1 Cr
#
#        location Carpet Area         Status            Floor Furnishing  \
# 159794      goa     111 sqm  Ready to Move       1 out of 3  Furnished
# 159948      goa      93 sqm  Ready to Move       2 out of 2  Furnished
# 159981      goa      56 sqm  Ready to Move  Ground out of 3  Furnished
#
#        Bathroom Balcony Ownership
# 159794        2       4  Freehold
# 159948        2       1  Freehold
# 159981        1       2  Freehold

# %%
status['Status'].unique()
# Out:
# array(['Ready to Move'], dtype=object)

# %%
# creating the final dataframe
final_dataframe=pd.DataFrame(status)
final_dataframe
# Out:
#                                                     Title  \
# 159794       2 BHK Ready to Occupy Flat for sale Porvorim
# 159948      2 BHK Ready to Occupy Flat for sale Calangute
# 159981        1 BHK Ready to Occupy Flat for sale Assagao
# 159371       2 BHK Ready to Occupy Flat for sale Porvorim
# 159822        1 BHK Ready to Occupy Flat for sale Pilerne
# ...                                                   ...
# 159711      1 BHK Ready to Occupy Flat for sale Calangute
# 159708  1 BHK Ready to Occupy Flat for sale in TATA Ri...
# 160012          1 BHK Ready to Occupy Flat for sale Varca
# 160172         2 BHK Ready to Occupy Flat for sale Arpora
# 160256  3 BHK Ready to Occupy Flat for sale in Sattva ...
#
#                                               Description Amount(in rupees)  \
# 159794  This magnificent 2 BHK Flat is available for s...             1 Cr
# 159948  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
# ...

# %%
final_dataframe=final_dataframe.reset_index()
# final_dataframe=final_dataframe.drop(["index","level_0"])
final_dataframe.head(2)
# print(final_dataframe.info())
# Out:
#     index                                          Title  \
# 0  159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 1  159948  2 BHK Ready to Occupy Flat for sale Calangute
#
#                                          Description Amount(in rupees)  \
# 0  This magnificent 2 BHK Flat is available for s...             1 Cr
# 1  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
#
#   location Carpet Area         Status       Floor Furnishing Bathroom Balcony  \
# 0      goa     111 sqm  Ready to Move  1 out of 3  Furnished        2       4
# 1      goa      93 sqm  Ready to Move  2 out of 2  Furnished        2       1
#
#   Ownership
# 0  Freehold
# 1  Freehold

# %%
final_dataframe.duplicated().sum()
# Out:
# 0

# %%
# final_dataframe['Carpet_Area(sqm)']=final_dataframe['Carpet_Area(sqrt)'].replace('sqm',"")
# final_dataframe.head()

# %%
final_dataframe.drop_duplicates(inplace=True)

# %%
final_dataframe=final_dataframe.rename(columns={'Carpet Area':'Carpet_Area(sqrt)'})
final_dataframe.head(2)
# Out:
#     index                                          Title  \
# 0  159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 1  159948  2 BHK Ready to Occupy Flat for sale Calangute
#
#                                          Description Amount(in rupees)  \
# 0  This magnificent 2 BHK Flat is available for s...             1 Cr
# 1  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
#
#   location Carpet_Area(sqrt)         Status       Floor Furnishing Bathroom  \
# 0      goa           111 sqm  Ready to Move  1 out of 3  Furnished        2
# 1      goa            93 sqm  Ready to Move  2 out of 2  Furnished        2
#
#   Balcony Ownership
# 0       4  Freehold
# 1       1  Freehold

# %%
final_dataframe['Carpet_Area(sqrt)'].dtypes
# Out:
# dtype('O')

# %%
# final_dataframe['Carpet_Area(sqrt)'].head(4)

# %%
final_dataframe.head(2)
# Out:
#     index                                          Title  \
# 0  159794   2 BHK Ready to Occupy Flat for sale Porvorim
# 1  159948  2 BHK Ready to Occupy Flat for sale Calangute
#
#                                          Description Amount(in rupees)  \
# 0  This magnificent 2 BHK Flat is available for s...             1 Cr
# 1  This lovely 2 BHK Flat in Calangute, Goa is up...             1 Cr
#
#   location Carpet_Area(sqrt)         Status       Floor Furnishing Bathroom  \
# 0      goa           111 sqm  Ready to Move  1 out of 3  Furnished        2
# 1      goa            93 sqm  Ready to Move  2 out of 2  Furnished        2
#
#   Balcony Ownership
# 0       4  Freehold
# 1       1  Freehold
